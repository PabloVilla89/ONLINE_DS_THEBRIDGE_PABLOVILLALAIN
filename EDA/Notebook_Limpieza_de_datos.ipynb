# %%
#Carga de datos y unificacion de datos
import pandas as pd

# Cargar cada archivo CSV desde la subcarpeta 'datos'
df_2020_2024 = pd.read_csv("datos/informe_horario_para_usuarios (2020-2024).csv", delimiter=';')
df_2015_2019 = pd.read_csv("datos/informe_horario_para_usuarios (2015-2019).csv", delimiter=';')
df_2010_2014 = pd.read_csv("datos/informe_horario_para_usuarios (2010-2014).csv", delimiter=';')
df_2005_2009 = pd.read_csv("datos/informe_horario_para_usuarios (2005-2009).csv", delimiter=';')

# Combinar los DataFrames en uno solo
df = pd.concat([df_2020_2024, df_2015_2019, df_2010_2014, df_2005_2009], ignore_index=True)
# Out:
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_15668\942961044.py:8: DtypeWarning: Columns (3,6,9,12,14,20,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2005_2009 = pd.read_csv("datos/informe_horario_para_usuarios (2005-2009).csv", delimiter=';')

# %%
#Análisis preliminar
df.describe
# Out:
# <bound method NDFrame.describe of        CODEST     FECHA   HORA   DPV  DVMED  HRMAXABS  HRMAX  HRMED  HRMINABS  \
# 0        CA52  01/01/20  00:00  ,021  247,3       NaN   98,3   97,8       NaN
# 1        CA52  01/01/20  01:00  ,035  270,2       NaN   97,7   96,5       NaN
# 2        CA52  01/01/20  02:00  ,052  286,9       NaN   95,4   94,9       NaN
# 3        CA52  01/01/20  03:00  ,065  285,8       NaN   94,6   93,5       NaN
# 4        CA52  01/01/20  04:00   ,08  285,6       NaN     93     92       NaN
# ...       ...       ...    ...   ...    ...       ...    ...    ...       ...
# 173664   CA52  31/12/09  19:00  ,713  252,5       NaN  63,64  55,93       NaN
# 173665   CA52  31/12/09  20:00  ,803  263,4       NaN  50,91  50,27       NaN
# 173666   CA52  31/12/09  21:00  ,853  262,3       NaN  49,02  45,97       NaN
# 173667   CA52  31/12/09  22:00  ,798  267,3       NaN  55,89  46,37       NaN
# 173668   CA52  31/12/09  23:00  ,611  285,1       NaN   56,1  54,91       NaN
#
#         HRMIN  ...  RRMED  RVIENTO TMAXABS   TMAX   TMED TMINABS   TMIN  \
# 0        97,3  ...    NaN   4,3416     NaN  6,908  6,459     NaN  6,032
# 1        95,8  ...    NaN   5,2164     NaN   7,38   7,05     NaN  6,639
# 2        94,6  ...    NaN   9,2988     NaN   7,31   7,14     NaN   7,04
# 3        92,3  ...    NaN   7,8912     NaN   7,24   7,04     NaN   6,84
# 4        90,5  ...    NaN   8,4852     NaN   7,18  6,941     NaN  6,839
# ...       ...  ...    ...      ...     ...    ...    ...     ...    ...
# 173664  49,56  ...    NaN  22,1112     NaN  14,55  14,16     NaN  13,74
# 173665  48,01  ...    NaN    25,38     NaN  14,41  14,17     NaN   13,8
# 173666  41,88  ...    NaN  24,3324     NaN  14,07  13,81     NaN  13,47
# 173667   43,1  ...    NaN  21,9348     NaN  13,47  12,88     NaN  11,45
# 173668  51,39  ...    NaN   22,212     NaN  11,86  11,48     NaN  11,19
#
#         VVMAX  VVMED  Unnamed: 26
# 0       2,176  1,206          NaN
# 1       3,753  1,449          NaN
# 2       4,155  2,583          NaN
# 3       3,538  2,192          NaN
# 4       3,891  2,357          NaN
# ...       ...    ...          ...
# 173664  11,12  6,142          NaN
# 173665  10,97   7,05          NaN
# 173666  12,48  6,759          NaN
# 173667  10,16  6,093          NaN
# 173668   9,39   6,17          NaN
#
# [173669 rows x 27 columns]>

# %%
df.dtypes
# Out:
# CODEST          object
# FECHA           object
# HORA            object
# DPV             object
# DVMED           object
# HRMAXABS       float64
# HRMAX           object
# HRMED           object
# HRMINABS       float64
# HRMIN           object
# PRECMAX        float64
# PREC            object
# DEWPT           object
# RADACU         float64
# RADMAX          object
# RADMED          object
# RRMAX          float64
# RRMED          float64
# RVIENTO         object
# TMAXABS        float64
# TMAX            object
# TMED            object
# TMINABS        float64
# TMIN            object
# VVMAX           object
# VVMED           object
# Unnamed: 26    float64
# dtype: object

# %%
# Resumen estadístico y número de valores nulos por columna
resumen = df.describe(include='all').transpose()
resumen['Valores Nulos'] = df.isnull().sum()
resumen['Número de Datos'] = df.count()
resumen['Porcentaje de Valores Nulos'] = (df.isnull().sum() / len(df)) * 100

print(resumen)
# Out:
#               count unique       top    freq mean  std  min  25%  50%  75%  \
# CODEST       173669      1      CA52  173669  NaN  NaN  NaN  NaN  NaN  NaN
# FECHA        173669   7196  03/04/07      48  NaN  NaN  NaN  NaN  NaN  NaN
# HORA         173669     48     03:00    7190  NaN  NaN  NaN  NaN  NaN  NaN
# DPV          138612   4185         0    1141  NaN  NaN  NaN  NaN  NaN  NaN
# DVMED        173577  16814         0     337  NaN  NaN  NaN  NaN  NaN  NaN
# HRMAXABS        0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# HRMAX        138582   5008       100    1304  NaN  NaN  NaN  NaN  NaN  NaN
# HRMED        173236  10092      99,9    1292  NaN  NaN  NaN  NaN  NaN  NaN
# HRMINABS        0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# HRMIN        138562   5259       100     807  NaN  NaN  NaN  NaN  NaN  NaN
# PRECMAX         0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# PREC         173667    345         0  169099  NaN  NaN  NaN  NaN  NaN  NaN
# DEWPT        138611  12378     10,23     111  NaN  NaN  NaN  NaN  NaN  NaN
# RADACU          0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# RADMAX       139010  11117         0   56371  NaN  NaN  NaN  NaN  NaN  NaN
# RADMED       173667  23064         0   71709  NaN  NaN  NaN  NaN  NaN  NaN
# RRMAX           0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# RRMED           0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# RVIENTO      173578  12590         0     378  NaN  NaN  NaN  NaN  NaN  NaN
# TMAXABS         0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# TMAX         138951   3981     13,48     283  NaN  NaN  NaN  NaN  NaN  NaN
# TMED         173605   9188     15,65     110  NaN  NaN  NaN  NaN  NaN  NaN
# TMINABS         0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
# TMIN         138934   4263     13,07     305  NaN  NaN  NaN  NaN  NaN  NaN
# VVMAX        138921   1519     1,803     423  NaN  NaN  NaN  NaN  NaN  NaN
# VVMED        173578  12589         0     378  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 26     0.0    NaN       NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#              max  Valores Nulos  Número de Datos  Porcentaje de Valores Nulos
# CODEST       NaN              0           173669                     0.000000
# FECHA        NaN              0           173669                     0.000000
# HORA         NaN              0           173669                     0.000000
# DPV          NaN          35057           138612                    20.186101
# DVMED        NaN             92           173577                     0.052974
# HRMAXABS     NaN         173669                0                   100.000000
# HRMAX        NaN          35087           138582                    20.203375
# HRMED        NaN            433           173236                     0.249325
# HRMINABS     NaN         173669                0                   100.000000
# HRMIN        NaN          35107           138562                    20.214892
# PRECMAX      NaN         173669                0                   100.000000
# PREC         NaN              2           173667                     0.001152
# DEWPT        NaN          35058           138611                    20.186677
# RADACU       NaN         173669                0                   100.000000
# RADMAX       NaN          34659           139010                    19.956930
# RADMED       NaN              2           173667                     0.001152
# RRMAX        NaN         173669                0                   100.000000
# RRMED        NaN         173669                0                   100.000000
# RVIENTO      NaN             91           173578                     0.052399
# TMAXABS      NaN         173669                0                   100.000000
# TMAX         NaN          34718           138951                    19.990902
# TMED         NaN             64           173605                     0.036852
# TMINABS      NaN         173669                0                   100.000000
# TMIN         NaN          34735           138934                    20.000691
# VVMAX        NaN          34748           138921                    20.008176
# VVMED        NaN             91           173578                     0.052399
# Unnamed: 26  NaN         173669                0                   100.000000

# %%
# Detectar filas duplicadas
duplicados = df.duplicated()

# Mostrar las filas duplicadas
duplicados_df = df[duplicados]

print(f"Hay {len(duplicados_df)} filas duplicadas. Aquí están:")
print(duplicados_df)
# Out:
# Hay 21 filas duplicadas. Aquí están:
#       CODEST     FECHA   HORA    DPV  DVMED  HRMAXABS  HRMAX  HRMED  HRMINABS  \
# 40897   CA52  31/08/24  00:00    ,45  19,33       NaN   87,5   85,9       NaN
# 40899   CA52  31/08/24  01:00    ,59  11,77       NaN   82,9   81,8       NaN
# 40901   CA52  31/08/24  02:00   ,547  22,81       NaN   83,4     83       NaN
# 40903   CA52  31/08/24  03:00   ,673  26,14       NaN   80,6   78,8       NaN
# 40905   CA52  31/08/24  04:00   ,576  348,8       NaN   83,5   81,3       NaN
# 40907   CA52  31/08/24  05:00   ,623  340,1       NaN   80,8   79,3       NaN
# 40909   CA52  31/08/24  06:00   ,702  330,8       NaN     78   76,7       NaN
# 40911   CA52  31/08/24  07:00   ,935  14,29       NaN   75,2   71,9       NaN
# 40913   CA52  31/08/24  08:00   ,952  33,87       NaN   74,8   73,3       NaN
# 40915   CA52  31/08/24  09:00  1,174  52,44       NaN   73,2   69,2       NaN
# 40917   CA52  31/08/24  10:00  1,327  52,81       NaN  68,05  66,39       NaN
# 40919   CA52  31/08/24  11:00  1,682  59,92       NaN  64,08  60,45       NaN
# 40921   CA52  31/08/24  12:00  1,561  50,64       NaN  64,21  62,37       NaN
# 40923   CA52  31/08/24  13:00  1,691  59,02       NaN  60,84  60,28       NaN
# 40925   CA52  31/08/24  14:00  1,616   71,7       NaN   63,2  61,76       NaN
# 40927   CA52  31/08/24  15:00  1,523  64,06       NaN  65,62  62,94       NaN
# 40929   CA52  31/08/24  16:00  1,269  59,86       NaN  69,53  67,67       NaN
# 40931   CA52  31/08/24  17:00   ,985  45,19       NaN   74,8   73,3       NaN
# 40933   CA52  31/08/24  18:00   ,839  41,83       NaN   76,8   76,1       NaN
# 40935   CA52  31/08/24  19:00   ,773  43,13       NaN   79,1   77,4       NaN
# 40937   CA52  31/08/24  20:00   ,687  25,59       NaN   79,9   79,7       NaN
#
#        HRMIN  ...  RRMED  RVIENTO TMAXABS   TMAX   TMED TMINABS   TMIN  VVMAX  \
# 40897   83,7  ...    NaN  14,3064     NaN  25,24  25,06     NaN   24,9  6,684
# 40899   80,8  ...    NaN  15,6276     NaN  25,44  25,35     NaN  25,31  6,448
# 40901   82,6  ...    NaN  15,1488     NaN  25,38  25,31     NaN  25,24  6,978
# 40903   77,2  ...    NaN  12,0924     NaN  25,24  25,06     NaN  24,84  6,272
# 40905     78  ...    NaN   7,9704     NaN  24,77  24,55     NaN  24,23  3,695
# 40907   78,1  ...    NaN    7,038     NaN  24,37  24,18     NaN  23,89  3,244
# 40909   75,3  ...    NaN   7,2648     NaN  24,57  24,19     NaN  23,83  3,224
# 40911   70,4  ...    NaN  10,6668     NaN  26,45  25,81     NaN   24,9  5,606
# 40913   70,7  ...    NaN  17,8056     NaN  27,18  27,02     NaN  26,86   7,59
# 40915  63,67  ...    NaN  20,5848     NaN  28,72  28,09     NaN  27,58   8,33
# 40917  64,41  ...    NaN  19,3536     NaN  28,92  28,74     NaN  28,45   7,96
# 40919  57,82  ...    NaN  17,2476     NaN   30,6  30,02     NaN  29,26  6,821
# 40921  61,72  ...    NaN   18,234     NaN  29,86  29,61     NaN  29,33   7,69
# 40923  58,76  ...    NaN  16,7976     NaN   30,2  30,07     NaN  29,93   7,04
# 40925  60,37  ...    NaN  16,6752     NaN  30,33  29,92     NaN  29,39   7,26
# 40927  61,38  ...    NaN  15,9192     NaN  29,66  29,44     NaN  29,06  6,938
# 40929  64,48  ...    NaN  15,4656     NaN  29,06  28,63     NaN  28,18  6,889
# 40931   71,5  ...    NaN  15,5736     NaN  27,91  27,53     NaN  27,04  6,017
# 40933   74,6  ...    NaN  13,1184     NaN  27,04   26,7     NaN  26,39   6,87
# 40935   76,1  ...    NaN   9,7236     NaN  26,45   26,3     NaN  26,18  4,479
# 40937   79,3  ...    NaN   9,3312     NaN  26,12  26,11     NaN  26,05  4,508
#
#        VVMED  Unnamed: 26
# 40897  3,974          NaN
# 40899  4,341          NaN
# 40901  4,208          NaN
# 40903  3,359          NaN
# 40905  2,214          NaN
# 40907  1,955          NaN
# 40909  2,018          NaN
# 40911  2,963          NaN
# 40913  4,946          NaN
# 40915  5,718          NaN
# 40917  5,376          NaN
# 40919  4,791          NaN
# 40921  5,065          NaN
# 40923  4,666          NaN
# 40925  4,632          NaN
# 40927  4,422          NaN
# 40929  4,296          NaN
# 40931  4,326          NaN
# 40933  3,644          NaN
# 40935  2,701          NaN
# 40937  2,592          NaN
#
# [21 rows x 27 columns]

# %%
# Eliminar filas duplicadas
df_limpio = df.drop_duplicates()

# Comprobar el tamaño del DataFrame después de eliminar duplicados
print(f"El DataFrame limpio tiene {df_limpio.shape[0]} filas y {df_limpio.shape[1]} columnas.")
# Out:
# El DataFrame limpio tiene 173648 filas y 27 columnas.

# %%
# Contar valores nulos por columna
valores_nulos = df_limpio.isnull().sum()

# Mostrar los resultados
print(valores_nulos)
# Out:
# CODEST              0
# FECHA               0
# HORA                0
# DPV             35057
# DVMED              92
# HRMAXABS       173648
# HRMAX           35087
# HRMED             433
# HRMINABS       173648
# HRMIN           35107
# PRECMAX        173648
# PREC                2
# DEWPT           35058
# RADACU         173648
# RADMAX          34659
# RADMED              2
# RRMAX          173648
# RRMED          173648
# RVIENTO            91
# TMAXABS        173648
# TMAX            34718
# TMED               64
# TMINABS        173648
# TMIN            34735
# VVMAX           34748
# VVMED              91
# Unnamed: 26    173648
# dtype: int64

# %%
# Eliminar columnas con más del 50% de valores nulos
threshold = len(df_limpio) * 0.5
df_limpio = df_limpio.dropna(thresh=threshold, axis=1)

# Comprobar de nuevo los valores nulos
print(df_limpio.isnull().sum())
# Out:
# CODEST         0
# FECHA          0
# HORA           0
# DPV        35057
# DVMED         92
# HRMAX      35087
# HRMED        433
# HRMIN      35107
# PREC           2
# DEWPT      35058
# RADMAX     34659
# RADMED         2
# RVIENTO       91
# TMAX       34718
# TMED          64
# TMIN       34735
# VVMAX      34748
# VVMED         91
# dtype: int64

# %%
df_limpio
# Out:
#        CODEST     FECHA   HORA   DPV  DVMED  HRMAX  HRMED  HRMIN PREC  DEWPT  \
# 0        CA52  01/01/20  00:00  ,021  247,3   98,3   97,8   97,3    0  6,139
# 1        CA52  01/01/20  01:00  ,035  270,2   97,7   96,5   95,8    0  6,545
# 2        CA52  01/01/20  02:00  ,052  286,9   95,4   94,9   94,6    0  6,386
# 3        CA52  01/01/20  03:00  ,065  285,8   94,6   93,5   92,3    0  6,073
# 4        CA52  01/01/20  04:00   ,08  285,6     93     92   90,5    0  5,734
# ...       ...       ...    ...   ...    ...    ...    ...    ...  ...    ...
# 173664   CA52  31/12/09  19:00  ,713  252,5  63,64  55,93  49,56    0   5,46
# 173665   CA52  31/12/09  20:00  ,803  263,4  50,91  50,27  48,01    0  3,991
# 173666   CA52  31/12/09  21:00  ,853  262,3  49,02  45,97  41,88    0  2,379
# 173667   CA52  31/12/09  22:00  ,798  267,3  55,89  46,37   43,1    0   1,63
# 173668   CA52  31/12/09  23:00  ,611  285,1   56,1  54,91  51,39    0  2,734
#
#        RADMAX RADMED  RVIENTO   TMAX   TMED   TMIN  VVMAX  VVMED
# 0           0      0   4,3416  6,908  6,459  6,032  2,176  1,206
# 1           0      0   5,2164   7,38   7,05  6,639  3,753  1,449
# 2           0      0   9,2988   7,31   7,14   7,04  4,155  2,583
# 3           0      0   7,8912   7,24   7,04   6,84  3,538  2,192
# 4           0      0   8,4852   7,18  6,941  6,839  3,891  2,357
# ...       ...    ...      ...    ...    ...    ...    ...    ...
# 173664      0      0  22,1112  14,55  14,16  13,74  11,12  6,142
# 173665      0      0    25,38  14,41  14,17   13,8  10,97   7,05
# 173666      0      0  24,3324  14,07  13,81  13,47  12,48  6,759
# 173667      0      0  21,9348  13,47  12,88  11,45  10,16  6,093
# 173668      0      0   22,212  11,86  11,48  11,19   9,39   6,17
#
# [173648 rows x 18 columns]

# %%
#Formateamos el df_limpio
# Crear una copia de df_limpio llamada df_formateado
df_formateado = df_limpio.copy()

# Ahora procederemos a hacer los cambios de formato en df_formateado
# Convertir FECHA y HORA a un solo campo datetime
df_formateado['DATETIME'] = pd.to_datetime(df_formateado['FECHA'] + ' ' + df_formateado['HORA'], format='%d/%m/%y %H:%M')

# Establecer DATETIME como índice
df_formateado.set_index('DATETIME', inplace=True)


# Lista de columnas a convertir
columns_to_convert = ["DPV", "DVMED", "HRMAX", "HRMED", "HRMIN", "PREC", "DEWPT", "RADMAX", "RADMED", "RVIENTO", "TMAX", "TMED", "TMIN", "VVMAX", "VVMED"]

# Convertir columnas a tipos numéricos
for column in columns_to_convert:
    df_formateado[column] = pd.to_numeric(df_formateado[column].str.replace(',', '.'), errors='coerce')

# Verificar el resultado de las conversiones
print(df_formateado.info())

# Mostrar una vista general del DataFrame formateado
df_formateado.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 173648 entries, 2020-01-01 00:00:00 to 2009-12-31 23:00:00
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   CODEST   173648 non-null  object
#  1   FECHA    173648 non-null  object
#  2   HORA     173648 non-null  object
#  3   DPV      138591 non-null  float64
#  4   DVMED    173556 non-null  float64
#  5   HRMAX    138561 non-null  float64
#  6   HRMED    173215 non-null  float64
#  7   HRMIN    138541 non-null  float64
#  8   PREC     173646 non-null  float64
#  9   DEWPT    138590 non-null  float64
#  10  RADMAX   138989 non-null  float64
#  11  RADMED   173646 non-null  float64
#  12  RVIENTO  173557 non-null  float64
#  13  TMAX     138930 non-null  float64
#  14  TMED     173584 non-null  float64
#  15  TMIN     138913 non-null  float64
#  16  VVMAX    138900 non-null  float64
#  17  VVMED    173557 non-null  float64
# dtypes: float64(15), object(3)
# memory usage: 25.2+ MB
# None
#                     CODEST     FECHA   HORA    DPV  DVMED  HRMAX  HRMED  \
# DATETIME
# 2020-01-01 00:00:00   CA52  01/01/20  00:00  0.021  247.3   98.3   97.8
# 2020-01-01 01:00:00   CA52  01/01/20  01:00  0.035  270.2   97.7   96.5
# 2020-01-01 02:00:00   CA52  01/01/20  02:00  0.052  286.9   95.4   94.9
# 2020-01-01 03:00:00   CA52  01/01/20  03:00  0.065  285.8   94.6   93.5
# 2020-01-01 04:00:00   CA52  01/01/20  04:00  0.080  285.6   93.0   92.0
#
#                      HRMIN  PREC  DEWPT  RADMAX  RADMED  RVIENTO   TMAX  \
# DATETIME
# 2020-01-01 00:00:00   97.3   0.0  6.139     0.0     0.0   4.3416  6.908
# 2020-01-01 01:00:00   95.8   0.0  6.545     0.0     0.0   5.2164  7.380
# 2020-01-01 02:00:00   94.6   0.0  6.386     0.0     0.0   9.2988  7.310
# 2020-01-01 03:00:00   92.3   0.0  6.073     0.0     0.0   7.8912  7.240
# 2020-01-01 04:00:00   90.5   0.0  5.734     0.0     0.0   8.4852  7.180
#
#                       TMED   TMIN  VVMAX  VVMED
# DATETIME
# 2020-01-01 00:00:00  6.459  6.032  2.176  1.206
# 2020-01-01 01:00:00  7.050  6.639  3.753  1.449
# 2020-01-01 02:00:00  7.140  7.040  4.155  2.583
# 2020-01-01 03:00:00  7.040  6.840  3.538  2.192
# 2020-01-01 04:00:00  6.941  6.839  3.891  2.357

# %%
# Crear columnas de Mes, Año y Semana del Año para su posterior analisis
df_formateado['Month'] = df_formateado.index.month
df_formateado['Year'] = df_formateado.index.year
df_formateado['Week'] = df_formateado.index.isocalendar().week
df_formateado['Day'] = df_formateado.index.day

# Mostrar una vista general del DataFrame con las nuevas columnas
df_formateado.head()
# Out:
#                     CODEST     FECHA   HORA    DPV  DVMED  HRMAX  HRMED  \
# DATETIME
# 2020-01-01 00:00:00   CA52  01/01/20  00:00  0.021  247.3   98.3   97.8
# 2020-01-01 01:00:00   CA52  01/01/20  01:00  0.035  270.2   97.7   96.5
# 2020-01-01 02:00:00   CA52  01/01/20  02:00  0.052  286.9   95.4   94.9
# 2020-01-01 03:00:00   CA52  01/01/20  03:00  0.065  285.8   94.6   93.5
# 2020-01-01 04:00:00   CA52  01/01/20  04:00  0.080  285.6   93.0   92.0
#
#                      HRMIN  PREC  DEWPT  ...  RVIENTO   TMAX   TMED   TMIN  \
# DATETIME                                 ...
# 2020-01-01 00:00:00   97.3   0.0  6.139  ...   4.3416  6.908  6.459  6.032
# 2020-01-01 01:00:00   95.8   0.0  6.545  ...   5.2164  7.380  7.050  6.639
# 2020-01-01 02:00:00   94.6   0.0  6.386  ...   9.2988  7.310  7.140  7.040
# 2020-01-01 03:00:00   92.3   0.0  6.073  ...   7.8912  7.240  7.040  6.840
# 2020-01-01 04:00:00   90.5   0.0  5.734  ...   8.4852  7.180  6.941  6.839
#
#                      VVMAX  VVMED  Month  Year  Week  Day
# DATETIME
# 2020-01-01 00:00:00  2.176  1.206      1  2020     1    1
# 2020-01-01 01:00:00  3.753  1.449      1  2020     1    1
# 2020-01-01 02:00:00  4.155  2.583      1  2020     1    1
# 2020-01-01 03:00:00  3.538  2.192      1  2020     1    1
# 2020-01-01 04:00:00  3.891  2.357      1  2020     1    1
#
# [5 rows x 22 columns]

# %%
# Exportar el DataFrame a un archivo CSV separado por ;
df_formateado.to_csv("Registro_Climaticos_La_Aljorra_2005-2024.csv", sep=';', index=True)

print("El DataFrame ha sido exportado a 'Registro_Climaticos_La_Aljorra_2005-2024.csv' con ; como delimitador.")
# Out:
# El DataFrame ha sido exportado a 'Registro_Climaticos_La_Aljorra_2005-2024.csv' con ; como delimitador.

# %%
import missingno as msno

# Visualización de datos faltantes
plt.figure(figsize=(12, 6))
msno.matrix(df_formateado)
plt.title('Matriz de Datos Faltantes')
plt.show()

# Matriz de correlación de datos faltantes
plt.figure(figsize=(12, 6))
msno.heatmap(df_formateado)
plt.title('Matriz de Correlación de Datos Faltantes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import missingno as msno
#       3 # Visualización de datos faltantes
#       4 plt.figure(figsize=(12, 6))
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\missingno\__init__.py:1
# ----> 1 from .missingno import matrix
#       2 from .missingno import bar
#       3 from .missingno import heatmap
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\missingno\missingno.py:2
#       1 import numpy as np
# ----> 2 import matplotlib as mpl
#       3 from matplotlib import gridspec
#       4 import matplotlib.pyplot as plt
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:159
#     155 from packaging.version import parse as parse_version
#     157 # cbook must import matplotlib only within function
#     158 # definitions, so it is safe to import from it here.
# --> 159 from . import _api, _version, cbook, _docstring, rcsetup
#     160 from matplotlib.cbook import sanitize_sequence
#     161 from matplotlib._api import MatplotlibDeprecationWarning
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
#      25 from matplotlib import _api, cbook
# ---> 26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\__init__.py:1
# ----> 1 from .registry import BackendFilter, backend_registry  # noqa: F401
#       3 # NOTE: plt.switch_backend() (called at import time) will add a "backend"
#       4 # attribute here for backcompat.
#       5 _QT_FORCE_QT5_BINDING = False
#
# ModuleNotFoundError: No module named 'matplotlib.backends.registry'

# %%
# Histograma de distribuciones por columna
df_formateado.hist(figsize=(14, 12), bins=50)
plt.suptitle('Distribución de Variables Clave')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Histograma de distribuciones por columna
# ----> 2 df_formateado.hist(figsize=(14, 12), bins=50)
#       3 plt.suptitle('Distribución de Variables Clave')
#       4 plt.show()
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:250, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     145 def hist_frame(
#     146     data: DataFrame,
#     147     column: IndexLabel | None = None,
#    (...)
#     162     **kwargs,
#     163 ):
#     164     """
#     165     Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248         >>> hist = df.hist(bins=3)
#     249     """
# --> 250     plot_backend = _get_plot_backend(backend)
#     251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#    (...)
#     267         **kwargs,
#     268     )
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File c:\Users\Pablo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
# Verificar la coherencia de los datos temporales
fechas = df_formateado.index.to_series()

# Diferencias entre las fechas consecutivas
diferencias = fechas.diff().dt.total_seconds().dropna()

plt.figure(figsize=(12, 6))
plt.hist(diferencias, bins=50)
plt.title('Diferencias entre Fechas Consecutivas')
plt.xlabel('Segundos')
plt.ylabel('Frecuencia')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualización de distribuciones
fig, axes = plt.subplots(len(df_formateado.columns) // 3, 3, figsize=(15, 20))

for i, column in enumerate(df_formateado.columns):
    sns.histplot(df_formateado[column], ax=axes[i // 3, i % 3])
    axes[i // 3, i % 3].set_title(column)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 8
#       5 fig, axes = plt.subplots(len(df_formateado.columns) // 3, 3, figsize=(15, 20))
#       7 for i, column in enumerate(df_formateado.columns):
# ----> 8     sns.histplot(df_formateado[column], ax=axes[i // 3, i % 3])
#       9     axes[i // 3, i % 3].set_title(column)
#      11 plt.tight_layout()
#
# IndexError: index 7 is out of bounds for axis 0 with size 7
